# %%
from RUN import *
parts=['总体','旅游','零售','海运','航空','医疗']
counts = 0
for part in parts:
    stat = run_analysis(part)
    if counts == 0:
        stats = stat
    else:
        stats = pd.concat([stats, stat], axis=0)
    counts += 1
stats
# Out:
# 选出的最优滞后阶数 (by AIC): 10
#
# 模型摘要：
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 24, May, 2025
# Time:                     10:51:37
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    20.1199
# Nobs:                     952.000    HQIC:                   19.9872
# Log likelihood:          -12134.7    FPE:                4.41425e+08
# AIC:                      19.9055    Det(Omega_mle):     4.22577e+08
# --------------------------------------------------------------------
# Results for equation Series1
# ...
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const             146.722612       105.488718            1.391           0.164
# L1.Series1          0.905782         0.033058           27.400           0.000
# ...
